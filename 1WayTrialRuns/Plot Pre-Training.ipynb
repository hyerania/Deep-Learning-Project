# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
F = open("./PreTraining-Trial1/log_PreTraining_LossList.txt")
lines = F.readlines()
count = 0
lossError = []
for i in range(len(lines)):
    lossError.append(lines[i])
#     print(lines[i])
#     count+=1
# print (lines)
# print(len(running_losslist))
# axes = plt.gca()

x_vals = np.arange(0, len(lines))
fig, ax1 = plt.subplots(figsize=(15, 15))
# plt.locator_params(axis='y', nbins=2)
plt.plot(x_vals, lossError)
every_nth = 500
for n, label in enumerate(ax1.yaxis.get_ticklabels()):
    if n % every_nth != 0:
        label.set_visible(False)
# ax1.locator_params(nbins=4, axis='y')

# plt.xlabel("iteration")
# plt.ylabel("error")
# plt.savefig("gen1_pretrain")
plt.show()
# plt.savefig('PreTrainLoss')
